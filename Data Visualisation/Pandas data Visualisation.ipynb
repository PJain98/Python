# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.401117
# 2019-06-08 -0.775146
# 2019-06-09  0.654553
# 2019-06-10  0.623220
# 2019-06-11  0.390271

# %%
ts.plot()

# %%
ts.plot(figsize=(20,5))

# %%
plt.plot(ts)

# %%
ts.head()
# Out:
# 2019-06-07   -0.534895
# 2019-06-08   -1.015888
# 2019-06-09   -1.096307
# 2019-06-10   -0.185754
# 2019-06-11    1.636490
# Freq: D, dtype: float64

# %%
ts=ts.cumsum()

# %%
ts.head()
# Out:
# 2019-06-07   -0.534895
# 2019-06-08   -1.550782
# 2019-06-09   -2.647089
# 2019-06-10   -2.832843
# 2019-06-11   -1.196353
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(10,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
df.head()
# Out:
#                value
# 2019-06-07 -0.401117
# 2019-06-08 -0.775146
# 2019-06-09  0.654553
# 2019-06-10  0.623220
# 2019-06-11  0.390271

# %%
df=df.cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.401117
# 2019-06-08 -1.176263
# 2019-06-09 -0.521710
# 2019-06-10  0.101510
# 2019-06-11  0.491781

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')     # iris dataset is already available  in seaborn(flower dataset)
iris.head()                         # in this dataset we have 3 species
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind="bar")

# %%
df = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.433382  0.356647 -0.522789  0.959431
# 1 -1.545858  0.523762 -0.943076  1.621785
# 2  0.583196  0.874110 -1.849431 -1.022617
# 3  0.811907 -0.720436 -0.731573  1.072713
# 4  1.300622  1.710597 -0.433750 -0.300180
# 5 -1.027574 -0.368383 -2.697519  1.240377
# 6  0.160385 -0.131453  0.885407 -0.051586
# 7 -0.860452 -1.144852 -1.099341 -1.409754
# 8 -0.544441  1.290570  0.832283  0.689583
# 9 -0.022541  0.431905 -0.349565 -1.063300

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x23ea20b16d0>,
#  <matplotlib.lines.Line2D at 0x23ea20b17c0>,
#  <matplotlib.lines.Line2D at 0x23ea20b1880>,
#  <matplotlib.lines.Line2D at 0x23ea20b1940>]

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris["sepal_length"].plot(kind = 'hist',figsize=(10,5))

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50)    # stacked= True means smaller data in front and larger data in back

# %%
iris.plot(kind = 'hist', stacked = False, bins = 50)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].head(7)
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# 5    3.9
# 6    3.4
# Name: sepal_width, dtype: float64

# %%
iris['sepal_width'].diff().head(7)
# Out:
# 0    NaN
# 1   -0.5
# 2    0.2
# 3   -0.1
# 4    0.5
# 5    0.3
# 6   -0.5
# Name: sepal_width, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind="hist" ,stacked=True,bins=50)

# %%
df = iris.drop(['species'],axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["fare"].plot(figsize=(20,8))

# %%
titanic["survived"].plot(kind="hist", title="plot for survived col")

# %%
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'red', alpha = 0.7, figsize=(10,10))    # alpha is for intensity of colour(how dark or how light colour is)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA3DDD1F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA3F8A7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA3FB3EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA3FE9670>]],
#       dtype=object)

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',c="red")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',c = 'sepal_width', s=30)   #( C for colour variation)
                                                                                # ( s for size of each dot)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, C = 'sepal_width')  # (for hexagon dots)

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
d=df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4551340>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4573A60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA459D0D0>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 15, autopct = '%.2f') #autopct is for percentage and %.2f means
                                                                                # upto 2 decimal points
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4639310>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA46607F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA467FE20>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df.plot.kde(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4DD4BB0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4F727F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4E04A30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA4E31BB0>],
#       dtype=object)

# %%
ts.plot(style = 'r-', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.plot(legend = True, figsize = (10, 5), logx = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA63D12B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA63E6C40>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA6402E20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000023EA6427B50>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8)) # layout=(2,2) means 2 rows and 2 column of fig.
plt.tight_layout()

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)
